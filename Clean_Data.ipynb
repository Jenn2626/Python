# %% [markdown]
# <a href="https://colab.research.google.com/github/Jenn2626/Python/blob/main/Clean_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df_sales = pd.read_csv('/content/sales_for _clean.csv')

# %%
df_sales.info()
df_sales.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  1025 non-null   int64
#  1   JoinDate    1025 non-null   object
#  2   Unused      0 non-null      float64
#  3   Mobile      1025 non-null   float64
#  4   Name        923 non-null    object
#  5   Email       929 non-null    object
#  6   Product     1025 non-null   object
#  7   Scores      898 non-null    float64
#  8   Birthdate   1025 non-null   object
#  9   Revenue     1025 non-null   object
#  10  Order_Date  1025 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 88.2+ KB
#    CustomerID                     JoinDate  Unused        Mobile  \
# 0           1                       8/7/19     NaN  8.433361e+10
# 1           2                      9/10/18     NaN  9.734441e+08
# 2           3                     20190630     NaN  3.382630e+08
# ...

# %%
# Convert to datetime
# Joindate datatype is timestamp, need to split lay date k lay time
df_sales['JoinDate'] = df_sales['JoinDate'].str.split().str[0]
df_sales
# Out:
#       CustomerID    JoinDate  Unused        Mobile              Name  \
# 0              1      8/7/19     NaN  8.433361e+10  mIChAel mIcHALek
# 1              2     9/10/18     NaN  9.734441e+08    Andrew Jimenez
# 2              3    20190630     NaN  3.382630e+08           Ann Gow
# 3              4  2019-09-06     NaN  8.496607e+10        James Chen
# 4              5    20170812     NaN  8.476707e+10   Dollie Martinez
# ...          ...         ...     ...           ...               ...
# 1020        1021     8/15/21     NaN  8.496412e+10         RubEN rAy
# 1021        1022      6/8/21     NaN  8.435878e+10     tImoTHy wiLEY
# 1022        1023      7/2/22     NaN  8.476342e+10    ValaRiE EchoLS
# 1023        1024     7/24/19     NaN  8.412880e+11        MArtA WOng
# 1024        1025     10/6/22     NaN  8.433743e+10     denNis rePiNE
#
#                         Email      Product  Scores Birthdate Revenue  \
# ...

# %%
# Convert to datetime
date_col =['JoinDate','Birthdate','Order_Date']
for col in date_col:
  df_sales[col] = pd.to_datetime(df_sales[col])
df_sales.info()
df_sales.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  1025 non-null   int64
#  1   JoinDate    1025 non-null   datetime64[ns]
#  2   Unused      0 non-null      float64
#  3   Mobile      1025 non-null   float64
#  4   Name        923 non-null    object
#  5   Email       929 non-null    object
#  6   Product     1025 non-null   object
#  7   Scores      898 non-null    float64
#  8   Birthdate   1025 non-null   datetime64[ns]
#  9   Revenue     1025 non-null   object
#  10  Order_Date  1025 non-null   datetime64[ns]
# dtypes: datetime64[ns](3), float64(3), int64(1), object(4)
# memory usage: 88.2+ KB
# /tmp/ipykernel_5243/1158708441.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# ...

# %%
# Conver to numeric
df_sales['Revenue'] = df_sales['Revenue'].str.replace('$','')
df_sales['Revenue'] = pd.to_numeric(df_sales['Revenue'])
df_sales.head(5)
# Out:
#    CustomerID   JoinDate  Unused        Mobile              Name  \
# 0           1 2019-08-07     NaN  8.433361e+10  mIChAel mIcHALek
# 1           2 2018-09-10     NaN  9.734441e+08    Andrew Jimenez
# 2           3 2019-06-30     NaN  3.382630e+08           Ann Gow
# 3           4 2019-09-06     NaN  8.496607e+10        James Chen
# 4           5 2017-08-12     NaN  8.476707e+10   Dollie Martinez
#
#                      Email      Product  Scores  Birthdate  Revenue Order_Date
# 0    contact812@domain.com       Tablet    66.0 1997-02-10     7877 2023-09-07
# 1    service45@example.com        table    53.0 2071-08-23     6087 2023-01-09
# 2      service699@test.com   SMARTPHONE    77.0 1983-11-05     1105 2023-08-07
# 3  customer575@example.com        table    58.0 1998-12-21     1019 2023-07-27
# 4      admin235@domain.com   Smartphone     NaN 2005-08-25     2985 2023-10-05

# %%
# Convert to string
str_col =['CustomerID','Mobile']
for col in str_col:
  df_sales[col] = df_sales[col].astype(str)
df_sales.head(5)
# Out:
#   CustomerID   JoinDate  Unused         Mobile              Name  \
# 0          1 2019-08-07     NaN  84333605993.0  mIChAel mIcHALek
# 1          2 2018-09-10     NaN    973444062.0    Andrew Jimenez
# 2          3 2019-06-30     NaN    338262954.0           Ann Gow
# 3          4 2019-09-06     NaN  84966068026.0        James Chen
# 4          5 2017-08-12     NaN  84767065885.0   Dollie Martinez
#
#                      Email      Product  Scores  Birthdate  Revenue Order_Date
# 0    contact812@domain.com       Tablet    66.0 1997-02-10     7877 2023-09-07
# 1    service45@example.com        table    53.0 2071-08-23     6087 2023-01-09
# 2      service699@test.com   SMARTPHONE    77.0 1983-11-05     1105 2023-08-07
# 3  customer575@example.com        table    58.0 1998-12-21     1019 2023-07-27
# 4      admin235@domain.com   Smartphone     NaN 2005-08-25     2985 2023-10-05

# %%
# Convert Mobile
# Split
df_sales['Mobile'] = df_sales['Mobile'].str.split('.').str[0]
df_sales.head(5)
# Out:
#   CustomerID   JoinDate  Unused       Mobile              Name  \
# 0          1 2019-08-07     NaN  84333605993  mIChAel mIcHALek
# 1          2 2018-09-10     NaN    973444062    Andrew Jimenez
# 2          3 2019-06-30     NaN    338262954           Ann Gow
# 3          4 2019-09-06     NaN  84966068026        James Chen
# 4          5 2017-08-12     NaN  84767065885   Dollie Martinez
#
#                      Email      Product  Scores  Birthdate  Revenue Order_Date
# 0    contact812@domain.com       Tablet    66.0 1997-02-10     7877 2023-09-07
# 1    service45@example.com        table    53.0 2071-08-23     6087 2023-01-09
# 2      service699@test.com   SMARTPHONE    77.0 1983-11-05     1105 2023-08-07
# 3  customer575@example.com        table    58.0 1998-12-21     1019 2023-07-27
# 4      admin235@domain.com   Smartphone     NaN 2005-08-25     2985 2023-10-05

# %%
# Condition add '84' in Mobile
def clean_mobile(x):
  if x.startswith('84'):
    return x
  else:
    return '84' + x
df_sales['Mobile'] = df_sales['Mobile'].apply(clean_mobile)
df_sales.head(5)
# Out:
#   CustomerID   JoinDate  Unused       Mobile              Name  \
# 0          1 2019-08-07     NaN  84333605993  mIChAel mIcHALek
# 1          2 2018-09-10     NaN  84973444062    Andrew Jimenez
# 2          3 2019-06-30     NaN  84338262954           Ann Gow
# 3          4 2019-09-06     NaN  84966068026        James Chen
# 4          5 2017-08-12     NaN  84767065885   Dollie Martinez
#
#                      Email      Product  Scores  Birthdate  Revenue Order_Date
# 0    contact812@domain.com       Tablet    66.0 1997-02-10     7877 2023-09-07
# 1    service45@example.com        table    53.0 2071-08-23     6087 2023-01-09
# 2      service699@test.com   SMARTPHONE    77.0 1983-11-05     1105 2023-08-07
# 3  customer575@example.com        table    58.0 1998-12-21     1019 2023-07-27
# 4      admin235@domain.com   Smartphone     NaN 2005-08-25     2985 2023-10-05

# %%
#Convert Name
df_sales['Name'] = df_sales['Name'].str.title()
df_sales.head(5)
# Out:
#   CustomerID   JoinDate  Unused       Mobile              Name  \
# 0          1 2019-08-07     NaN  84333605993  Michael Michalek
# 1          2 2018-09-10     NaN  84973444062    Andrew Jimenez
# 2          3 2019-06-30     NaN  84338262954           Ann Gow
# 3          4 2019-09-06     NaN  84966068026        James Chen
# 4          5 2017-08-12     NaN  84767065885   Dollie Martinez
#
#                      Email      Product  Scores  Birthdate  Revenue Order_Date
# 0    contact812@domain.com       Tablet    66.0 1997-02-10     7877 2023-09-07
# 1    service45@example.com        table    53.0 2071-08-23     6087 2023-01-09
# 2      service699@test.com   SMARTPHONE    77.0 1983-11-05     1105 2023-08-07
# 3  customer575@example.com        table    58.0 1998-12-21     1019 2023-07-27
# 4      admin235@domain.com   Smartphone     NaN 2005-08-25     2985 2023-10-05

# %%
# Convert Product
# Count values product to know how product category
df_sales['Product'].value_counts()
# Out:
# Product
#  SMARTPHONE     178
# Tablet          176
# Smartphone      172
# Laptop          169
# Laptop          165
# tablet          148
# table             8
# Smart phone       4
# Lap               3
#  SMAR TPHONE      1
# Table             1
# Name: count, dtype: int64

# %%
# Strip blank
df_sales['Product'] = df_sales['Product'].str.strip()
df_sales['Product'].value_counts()
# Out:
# Product
# Laptop         334
# SMARTPHONE     178
# Tablet         176
# Smartphone     172
# tablet         148
# table            8
# Smart phone      4
# Lap              3
# SMAR TPHONE      1
# Table            1
# Name: count, dtype: int64

# %%
df_sales['Product']= df_sales['Product'].str.title()
df_sales['Product'].value_counts()
# Out:
# Product
# Smartphone     350
# Laptop         334
# Tablet         324
# Table            9
# Smart Phone      4
# Lap              3
# Smar Tphone      1
# Name: count, dtype: int64

# %%
# Condition logic
def clean_Product(x):
  if x in ['Smart Phone','Smar Tphone']:
    return 'Smartphone'
  elif x in ['Lap']:
    return 'Laptop'
  elif x in ['Table']:
    return 'Tablet'
  else:
    return x
df_sales['Product'] = df_sales['Product'].apply(clean_Product)
df_sales['Product'].value_counts()
# Out:
# Product
# Smartphone    355
# Laptop        337
# Tablet        333
# Name: count, dtype: int64

# %%
df_sales.head(5)
# Out:
#   CustomerID   JoinDate  Unused       Mobile              Name  \
# 0          1 2019-08-07     NaN  84333605993  Michael Michalek
# 1          2 2018-09-10     NaN  84973444062    Andrew Jimenez
# 2          3 2019-06-30     NaN  84338262954           Ann Gow
# 3          4 2019-09-06     NaN  84966068026        James Chen
# 4          5 2017-08-12     NaN  84767065885   Dollie Martinez
#
#                      Email     Product  Scores  Birthdate  Revenue Order_Date
# 0    contact812@domain.com      Tablet    66.0 1997-02-10     7877 2023-09-07
# 1    service45@example.com      Tablet    53.0 2071-08-23     6087 2023-01-09
# 2      service699@test.com  Smartphone    77.0 1983-11-05     1105 2023-08-07
# 3  customer575@example.com      Tablet    58.0 1998-12-21     1019 2023-07-27
# 4      admin235@domain.com  Smartphone     NaN 2005-08-25     2985 2023-10-05

# %%
# Create find missing data function
def find_missing_value(df):
  missing_data = df.isnull().sum().to_frame('count_null')
  missing_data['percent_null'] = missing_data['count_null']/len(missing_data)
  return missing_data
find_missing_value(df_sales)
#
# Out:
#             count_null  percent_null
# CustomerID           0      0.000000
# JoinDate             0      0.000000
# Unused            1025     93.181818
# Mobile               0      0.000000
# Name               102      9.272727
# Email               96      8.727273
# Product              0      0.000000
# Scores             127     11.545455
# Birthdate            0      0.000000
# Revenue              0      0.000000
# Order_Date           0      0.000000

# %%
# Drop Unused
df_sales = df_sales.drop(columns='Unused')
df_sales.head(5)
# Out:
#   CustomerID   JoinDate       Mobile              Name  \
# 0          1 2019-08-07  84333605993  Michael Michalek
# 1          2 2018-09-10  84973444062    Andrew Jimenez
# 2          3 2019-06-30  84338262954           Ann Gow
# 3          4 2019-09-06  84966068026        James Chen
# 4          5 2017-08-12  84767065885   Dollie Martinez
#
#                      Email     Product  Scores  Birthdate  Revenue Order_Date
# 0    contact812@domain.com      Tablet    66.0 1997-02-10     7877 2023-09-07
# 1    service45@example.com      Tablet    53.0 2071-08-23     6087 2023-01-09
# 2      service699@test.com  Smartphone    77.0 1983-11-05     1105 2023-08-07
# 3  customer575@example.com      Tablet    58.0 1998-12-21     1019 2023-07-27
# 4      admin235@domain.com  Smartphone     NaN 2005-08-25     2985 2023-10-05

# %%
# Find duplicate by each row

df_sales[df_sales.duplicated()]
# Out:
# Empty DataFrame
# Columns: [CustomerID, JoinDate, Mobile, Name, Email, Product, Scores, Birthdate, Revenue, Order_Date]
# Index: []

# %%
# Find duplicate by 1 column
df_sales[df_sales['CustomerID'].duplicated()]
# Out:
#    CustomerID   JoinDate        Mobile               Name  \
# 14         15 2018-04-18  841267000000                NaN
# 24         22 2019-09-02   84978909747                NaN
# 32         27 2019-07-23   84974404339  Lawrence Cummings
# 42         42 2018-10-18  841288000000                NaN
#
#                      Email     Product  Scores  Birthdate  Revenue Order_Date
# 14                     NaN      Tablet    61.0 2064-05-22     1041 2023-05-09
# 24  contact159@example.com      Tablet    75.0 2066-04-05     5514 2023-05-29
# 32                     NaN  Smartphone    73.0 1993-05-17     5195 2023-08-16
# 42       admin576@test.com      Tablet   100.0 1994-11-17     7141 2023-07-19

# %%
# Show up all row duplicate  check by CustomerID
df_sales[df_sales['CustomerID'].duplicated(keep = False)]
# Out:
#    CustomerID   JoinDate        Mobile               Name  \
# 13         15 2017-12-10   84356173988         Paul Ruper
# 14         15 2018-04-18  841267000000                NaN
# 21         22 2018-05-28   84334263580       Laura Beatty
# 24         22 2019-09-02   84978909747                NaN
# 26         27 2018-03-21  841266000000      James Johnson
# 32         27 2019-07-23   84974404339  Lawrence Cummings
# 41         42 2019-05-21  841266000000                NaN
# 42         42 2018-10-18  841288000000                NaN
#
#                      Email     Product  Scores  Birthdate  Revenue Order_Date
# 13     admin929@domain.com      Tablet     NaN 1998-11-15      433 2023-11-29
# 14                     NaN      Tablet    61.0 2064-05-22     1041 2023-05-09
# 21     admin179@domain.com  Smartphone    88.0 1985-01-18     9023 2023-08-28
# 24  contact159@example.com      Tablet    75.0 2066-04-05     5514 2023-05-29
# ...

# %%
# Drop duplicate by method keep the last one
df_sales = df_sales.drop_duplicates('CustomerID',keep = 'last')
df_sales[df_sales['CustomerID'].duplicated(keep = False)]
# Out:
# Empty DataFrame
# Columns: [CustomerID, JoinDate, Mobile, Name, Email, Product, Scores, Birthdate, Revenue, Order_Date]
# Index: []

# %%
# Define function find missing value
def find_missing_value(df):
  missing_data = df.isnull().sum().to_frame('count_null')
  missing_data['percent_null'] = missing_data['count_null']/len(missing_data)
  return missing_data
find_missing_value(df_sales)
# Out:
#             count_null  percent_null
# CustomerID           0           0.0
# JoinDate             0           0.0
# Mobile               0           0.0
# Name               101          10.1
# Email               96           9.6
# Product              0           0.0
# Scores             125          12.5
# Birthdate            0           0.0
# Revenue              0           0.0
# Order_Date           0           0.0

# %%
# Input missing data in column 'score' by mean score


df_sales['Scores']=df_sales['Scores'].fillna(df_sales['Scores'].mean())
df_sales['Scores'] = df_sales['Scores'].round(2)
df_sales.head(5)
# Out:
#   CustomerID   JoinDate       Mobile              Name  \
# 0          1 2019-08-07  84333605993  Michael Michalek
# 1          2 2018-09-10  84973444062    Andrew Jimenez
# 2          3 2019-06-30  84338262954           Ann Gow
# 3          4 2019-09-06  84966068026        James Chen
# 4          5 2017-08-12  84767065885   Dollie Martinez
#
#                      Email     Product  Scores  Birthdate  Revenue Order_Date
# 0    contact812@domain.com      Tablet   66.00 1997-02-10     7877 2023-09-07
# 1    service45@example.com      Tablet   53.00 2071-08-23     6087 2023-01-09
# 2      service699@test.com  Smartphone   77.00 1983-11-05     1105 2023-08-07
# 3  customer575@example.com      Tablet   58.00 1998-12-21     1019 2023-07-27
# 4      admin235@domain.com  Smartphone   76.91 2005-08-25     2985 2023-10-05

# %%
find_missing_value(df_sales)
# Out:
#             count_null  percent_null
# CustomerID           0           0.0
# JoinDate             0           0.0
# Mobile               0           0.0
# Name               101          10.1
# Email               96           9.6
# Product              0           0.0
# Scores               0           0.0
# Birthdate            0           0.0
# Revenue              0           0.0
# Order_Date           0           0.0

# %%
# Replace na in Name by 'Unkown
df_sales['Name'] = df_sales['Name'].fillna('Unknown')
find_missing_value(df_sales)
# Out:
#             count_null  percent_null
# CustomerID           0           0.0
# JoinDate             0           0.0
# Mobile               0           0.0
# Name                 0           0.0
# Email               96           9.6
# Product              0           0.0
# Scores               0           0.0
# Birthdate            0           0.0
# Revenue              0           0.0
# Order_Date           0           0.0

# %%
# Replace na in Email by New Email( create by First Name. Last Name@), if New Email is na replace by 'Unkown'
# Create New Email
df_sales['New_Email'] = df_sales['Name'].str.split().str[0]+ '.'+df_sales['Name'].str.split().str[1]+'@python.com'
df_sales.head(5)
# Out:
#   CustomerID   JoinDate       Mobile              Name  \
# 0          1 2019-08-07  84333605993  Michael Michalek
# 1          2 2018-09-10  84973444062    Andrew Jimenez
# 2          3 2019-06-30  84338262954           Ann Gow
# 3          4 2019-09-06  84966068026        James Chen
# 4          5 2017-08-12  84767065885   Dollie Martinez
#
#                      Email     Product  Scores  Birthdate  Revenue Order_Date  \
# 0    contact812@domain.com      Tablet   66.00 1997-02-10     7877 2023-09-07
# 1    service45@example.com      Tablet   53.00 2071-08-23     6087 2023-01-09
# 2      service699@test.com  Smartphone   77.00 1983-11-05     1105 2023-08-07
# 3  customer575@example.com      Tablet   58.00 1998-12-21     1019 2023-07-27
# 4      admin235@domain.com  Smartphone   76.91 2005-08-25     2985 2023-10-05
#
#                      New_Email
# 0  Michael.Michalek@python.com
# 1    Andrew.Jimenez@python.com
# 2           Ann.Gow@python.com
# 3        James.Chen@python.com
# ...

# %%
find_missing_value(df_sales)
# Out:
#             count_null  percent_null
# CustomerID           0      0.000000
# JoinDate             0      0.000000
# Mobile               0      0.000000
# Name                 0      0.000000
# Email               96      8.727273
# Product              0      0.000000
# Scores               0      0.000000
# Birthdate            0      0.000000
# Revenue              0      0.000000
# Order_Date           0      0.000000
# New_Email          102      9.272727

# %%
# Replace na in Email by New Email
df_sales['Email'] = df_sales['Email'].fillna(df_sales['New_Email'])
df_sales.head(5)
# Out:
#   CustomerID   JoinDate       Mobile              Name  \
# 0          1 2019-08-07  84333605993  Michael Michalek
# 1          2 2018-09-10  84973444062    Andrew Jimenez
# 2          3 2019-06-30  84338262954           Ann Gow
# 3          4 2019-09-06  84966068026        James Chen
# 4          5 2017-08-12  84767065885   Dollie Martinez
#
#                      Email     Product  Scores  Birthdate  Revenue Order_Date  \
# 0    contact812@domain.com      Tablet   66.00 1997-02-10     7877 2023-09-07
# 1    service45@example.com      Tablet   53.00 2071-08-23     6087 2023-01-09
# 2      service699@test.com  Smartphone   77.00 1983-11-05     1105 2023-08-07
# 3  customer575@example.com      Tablet   58.00 1998-12-21     1019 2023-07-27
# 4      admin235@domain.com  Smartphone   76.91 2005-08-25     2985 2023-10-05
#
#                      New_Email
# 0  Michael.Michalek@python.com
# 1    Andrew.Jimenez@python.com
# 2           Ann.Gow@python.com
# 3        James.Chen@python.com
# ...

# %%
find_missing_value(df_sales)
# Out:
#             count_null  percent_null
# CustomerID           0      0.000000
# JoinDate             0      0.000000
# Mobile               0      0.000000
# Name                 0      0.000000
# Email                9      0.818182
# Product              0      0.000000
# Scores               0      0.000000
# Birthdate            0      0.000000
# Revenue              0      0.000000
# Order_Date           0      0.000000
# New_Email          102      9.272727

# %%
# Replace na in Email by 'Unknow'
df_sales['Email'] = df_sales['Email'].fillna('Unknown')
find_missing_value(df_sales)
# Out:
#             count_null  percent_null
# CustomerID           0      0.000000
# JoinDate             0      0.000000
# Mobile               0      0.000000
# Name                 0      0.000000
# Email                0      0.000000
# Product              0      0.000000
# Scores               0      0.000000
# Birthdate            0      0.000000
# Revenue              0      0.000000
# Order_Date           0      0.000000
# New_Email          102      9.272727
